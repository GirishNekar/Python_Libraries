# %% [markdown]
# """<br>
# Author: Girish <br>
# Date: 2024-08-12 <br>
# Last Modified by: Girish <br>
# Last Modified Time: 2024-08-12 <br>
# Title: Seaborn Library Progrms <br>
# """

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Seaborn Bar plot<h1>

# %% [markdown]
# 1. Write a program to draw bar plot of sex against survived for a dataset given in the url
# https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv

# %%
def load_data(url):
    
    
    """
    Description:
        Loads the Titanic dataset from the given URL.
        
    Parameter:
        url (str): The URL to the Titanic dataset.
        
    Returns:
        pd.DataFrame: The loaded Titanic dataset as a DataFrame.
    """
    
    return pd.read_csv(url)



def plot_sex_survived(df):
    
    
    
    """
    
    Description:
        Generates a bar plot of sex against survived using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing Titanic data.
        
    Returns:
        None
        
    """
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    sns.countplot(x='sex', hue='survived', data=df)
    plt.title("Bar Plot of Sex Against Survived")
    plt.xlabel("Sex")
    plt.ylabel("Count")
    plt.legend(title='Survived', loc='upper right')
    plt.show()



def main():

    url = "https://github.com/mwaskom/seaborn-data/raw/master/titanic.csv"
    df = load_data(url)
    plot_sex_survived(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# <h1>Seaborn pointplot<h1>

# %% [markdown]
# 1. Write a program to draw a point plot for sex against survived for a dataset given in url
# https://github.com/mwaskom/seaborn-data/blob/master/titanic.csv

# %%
def load_data(url):
    
    """
    Description:
        Loads the Titanic dataset from the given URL.
        
    Parameter:
        url (str): The URL to the Titanic dataset.
        
    Returns:
        pd.DataFrame: The loaded Titanic dataset as a DataFrame.
    """
    
    return pd.read_csv(url)



def plot_sex_survived_point(df):
    
    
    """
    Description:
        Generates a point plot of sex against survived using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing Titanic data.
        
    Returns:
        None
    """
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    sns.pointplot(x='sex', y='survived', data=df)
    plt.title("Point Plot of Sex Against Survived")
    plt.xlabel("Sex")
    plt.ylabel("Survival Rate")
    plt.show()


def main():

    url = "https://github.com/mwaskom/seaborn-data/raw/master/titanic.csv"
    df = load_data(url)
    plot_sex_survived_point(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# <h1>Seaborn Scatterplot<h1>

# %% [markdown]
# 1. Write a program to draw a scatter plot of “day” against “total bill” for a dataset given in a
# url
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def load_data(url):
    
    
    """
    Description:
        Loads the tips dataset from the given URL.
        
    Parameter:
        url (str): The URL to the tips dataset.
        
    Returns:
        pd.DataFrame: The loaded tips dataset as a DataFrame.
    """
    
    
    return pd.read_csv(url)



def plot_day_total_bill_scatter(df):
    
    
    """
    Description:
        Generates a scatter plot of day against total bill using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing tips data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    sns.scatterplot(x='day', y='total_bill', data=df)
    plt.title("Scatter Plot of Day Against Total Bill")
    plt.xlabel("Day")
    plt.ylabel("Total Bill")
    plt.show()



def main():

    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
    df = load_data(url)
    plot_day_total_bill_scatter(df)



if __name__ == "__main__":
    main()

# %% [markdown]
# <h1>Seaborn Violin Plot<h1>

# %% [markdown]
# 1. Write a program to draw a violin plot of sex against total_bill for a given dataset
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def load_data(url):
    
    
    """
    Description:
        Loads the tips dataset from the given URL.
        
    Parameter:
        url (str): The URL to the tips dataset.
        
    Returns:
        pd.DataFrame: The loaded tips dataset as a DataFrame.
    """
    
    
    return pd.read_csv(url)



def plot_sex_total_bill_violin(df):
    
    
    """
    Description:
        Generates a violin plot of sex against total bill using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing tips data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    sns.violinplot(x='sex', y='total_bill', data=df)
    plt.title("Violin Plot of Sex Against Total Bill")
    plt.xlabel("Sex")
    plt.ylabel("Total Bill")
    plt.show()



def main():

    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
    df = load_data(url)
    plot_sex_total_bill_violin(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# 2. Write a program to draw a violin plot of “species” against “sepal length” for a dataset
# given in a url
# https://github.com/mwaskom/seaborn-data/blob/master/iris.csv

# %%
def load_data(url):
    
    
    """
    Description:
        Loads the iris dataset from the given URL.
        
    Parameter:
        url (str): The URL to the iris dataset.
        
    Returns:
        pd.DataFrame: The loaded iris dataset as a DataFrame.
    """
    
    return pd.read_csv(url)



def plot_species_sepal_length_violin(df):
    
    
    """
    Description:
        Generates a violin plot of species against sepal length using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing iris data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(8, 6))
    sns.violinplot(x='species', y='sepal_length', data=df)
    plt.title("Violin Plot of Species Against Sepal Length")
    plt.xlabel("Species")
    plt.ylabel("Sepal Length (cm)")
    plt.show()



def main():

    url = "https://github.com/mwaskom/seaborn-data/raw/master/iris.csv"
    df = load_data(url)
    plot_species_sepal_length_violin(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# <h1 >Seaborn BoxPlot <h1>

# %% [markdown]
# 1. Write a program to draw box plot of life expectancy by continent for a data set given in a
# url
# https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapmind
# er-FiveYearData.csv

# %%
def load_data(url):
    
    
    """
    Description:
        Loads the Gapminder dataset from the given URL.
        
    Parameter:
        url (str): The URL to the Gapminder dataset.
        
    Returns:
        pd.DataFrame: The loaded Gapminder dataset as a DataFrame.
    """
    
    
    return pd.read_csv(url)



def plot_life_expectancy_box(df):
    
    
    """
    Description:
        Generates a box plot of life expectancy by continent using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing Gapminder data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='continent', y='lifeExp', data=df)
    plt.title("Box Plot of Life Expectancy by Continent")
    plt.xlabel("Continent")
    plt.ylabel("Life Expectancy")
    plt.show()



def main():

    url = "https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv"
    df = load_data(url)
    plot_life_expectancy_box(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# 2. Write a program to draw a box plot of day by tips for a dataset given in a url
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def load_data(url):
    
    
    """
    Description:
        Loads the tips dataset from the given URL.
        
    Parameter:
        url (str): The URL to the tips dataset.
        
    Returns:
        pd.DataFrame: The loaded tips dataset as a DataFrame.
    """
    
    
    return pd.read_csv(url)


def plot_tips_box(df):
    
    
    """
    Description:
        Generates a box plot of tips by day using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing tips data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='day', y='tip', data=df)
    plt.title("Box Plot of Tips by Day")
    plt.xlabel("Day")
    plt.ylabel("Tip Amount")
    plt.show()



def main():
    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
    df = load_data(url)
    plot_tips_box(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# <h1>Seaborn Swarm Plot<h1>

# %% [markdown]
# 1. Write a program to draw a swarm plot of total bill against size for a given dataset
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def load_data(url):
    
    """
    Description:
        Loads the tips dataset from the given URL.
        
    Parameter:
        url (str): The URL to the tips dataset.
        
    Returns:
        pd.DataFrame: The loaded tips dataset as a DataFrame.
    """
    
    return pd.read_csv(url)


def plot_total_bill_swarm(df):
    
    
    """
    Description:
        Generates a swarm plot of total bill against size using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing tips data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.swarmplot(x='size', y='total_bill', data=df)
    plt.title("Swarm Plot of Total Bill Against Size")
    plt.xlabel("Size of Party")
    plt.ylabel("Total Bill Amount")
    plt.show()


def main():
    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
    df = load_data(url)
    plot_total_bill_swarm(df)

if __name__ == "__main__":
    main()

# %% [markdown]
# 2. Write a program to draw swarm plot of “total bill” against day for a dataset given in url
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def load_data(url):
    
    """
    Description:
        Loads the tips dataset from the given URL.
        
    Parameter:
        url (str): The URL to the tips dataset.
        
    Returns:
        pd.DataFrame: The loaded tips dataset as a DataFrame.
    """
    
    return pd.read_csv(url)



def plot_total_bill_swarm(df):
    
    
    """
    Description:
        Generates a swarm plot of total bill against day using the provided DataFrame.
        
    Parameter:
        df (pd.DataFrame): The DataFrame containing tips data.
        
    Returns:
        None
    """
    
    
    sns.set_theme(style="whitegrid")
    plt.figure(figsize=(10, 6))
    sns.swarmplot(x='day', y='total_bill', data=df , color = 'r')
    plt.title("Swarm Plot of Total Bill Against Day")
    plt.xlabel("Day")
    plt.ylabel("Total Bill Amount")
    plt.show()


def main():
    url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
    df = load_data(url)
    plot_total_bill_swarm(df)

if __name__ == "__main__":
    main()
